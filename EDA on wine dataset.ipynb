# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:/Users/KRIPASAGAR CHAUDHARI/Desktop/SHWETA/excel/winequality-white.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# #conclusion:
# this dataset have a 4898 observation

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %% [markdown]
# #conclusion :
# the mean alcohol content is 10.51%
# volatile acidity-High maximum value (1.10) may indicate outliers.
# The mean free sulfur dioxide level is 35.30 and the mean total sulfur dioxide level is 138.36, and
# the wide range of these values indicates varying levels of wine preservation across the dataset.

# %%
df.shape
# Out:
# (4898, 12)

# %%
df['quality'].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9], dtype=int64)

# %% [markdown]
# df['quality'].value_counts()

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# #there is no null values

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 4893    False
# 4894    False
# 4895    False
# 4896    False
# 4897    False
# Length: 4898, dtype: bool

# %%
df[df.duplicated()]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.2              0.23         0.32             8.5      0.058
# 5               8.1              0.28         0.40             6.9      0.050
# 7               7.0              0.27         0.36            20.7      0.045
# 8               6.3              0.30         0.34             1.6      0.049
# 20              6.2              0.66         0.48             1.2      0.029
# ...             ...               ...          ...             ...        ...
# 4828            6.4              0.23         0.35            10.3      0.042
# 4850            7.0              0.36         0.35             2.5      0.048
# 4851            6.4              0.33         0.44             8.9      0.055
# 4856            7.1              0.23         0.39            13.7      0.058
# 4880            6.6              0.34         0.40             8.1      0.046
#
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (3961, 12)

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.019214     0.298959
# volatile acidity          -0.019214          1.000000    -0.163228
# citric acid                0.298959         -0.163228     1.000000
# residual sugar             0.083620          0.098340     0.106269
# chlorides                  0.024036          0.086287     0.132590
# free sulfur dioxide       -0.058396         -0.102471     0.091681
# total sulfur dioxide       0.082425          0.102315     0.122845
# density                    0.266091          0.060603     0.160076
# pH                        -0.431274         -0.046954    -0.183015
# sulphates                 -0.017453         -0.021150     0.049442
# alcohol                   -0.110788          0.046815    -0.076514
# quality                   -0.124636         -0.190678     0.007065
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.quality.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='quality'>

# %%
sns.displot(df["fixed acidity"])

# %%
sns.histplot(df["fixed acidity"])
# Out:
# <Axes: xlabel='fixed acidity', ylabel='Count'>

# %%
for i in df.columns:
    sns.histplot(df[i],kde=True)

# %%
# categorical plot
sns.catplot(x='quality',y='alcohol',data=df,kind='box')

# %%
sns.scatterplot(x='alcohol',y='pH',hue='quality',data=df)
# Out:
# <Axes: xlabel='alcohol', ylabel='pH'>
